# %%
import pandas as pd
import time
from datetime import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from collections import OrderedDict

commonAreas = ['Aberdeenshire',
 'Antrim and Newtownabbey',
 'Ards and North Down',
 'Armagh City, Banbridge and Craigavon',
 'Bath and North East Somerset',
 'Bedford',
 'Belfast',
 'Blackburn with Darwen',
 'Blackpool',
 'Blaenau Gwent',
 'Bracknell Forest',
 'Brighton and Hove',
 'Cardiff',
 'Carmarthenshire',
 'Causeway Coast and Glens',
 'Central Bedfordshire',
 'Ceredigion',
 'Cheshire East',
 'Cheshire West and Chester',
 'Clackmannanshire',
 'County Durham',
 'Darlington',
 'Denbighshire',
 'Derby',
 'Dorset',
 'Dumfries and Galloway',
 'East Riding of Yorkshire',
 'Falkirk',
 'Fermanagh and Omagh',
 'Fife',
 'Flintshire',
 'Glasgow City',
 'Gwynedd',
 'Hartlepool',
 'Inverclyde',
 'Isle of Anglesey',
 'Isle of Wight',
 'Leicester',
 'Lisburn and Castlereagh',
 'Luton',
 'Medway',
 'Mid Ulster',
 'Mid and East Antrim',
 'Middlesbrough',
 'Midlothian',
 'Milton Keynes',
 'Monmouthshire',
 'Moray',
 'Newport',
 'Newry, Mourne and Down',
 'North East Lincolnshire',
 'North Lanarkshire',
 'North Lincolnshire',
 'North Somerset',
 'Northumberland',
 'Nottingham',
 'Pembrokeshire',
 'Perth and Kinross',
 'Peterborough',
 'Plymouth',
 'Portsmouth',
 'Powys',
 'Reading',
 'Redcar and Cleveland',
 'Renfrewshire',
 'Rutland',
 'Scottish Borders',
 'Shetland Islands',
 'Shropshire',
 'Slough',
 'South Gloucestershire',
 'South Lanarkshire',
 'Southampton',
 'Southend-on-Sea',
 'Stirling',
 'Stockton-on-Tees',
 'Stoke-on-Trent',
 'Swansea',
 'Swindon',
 'Thurrock',
 'Torbay',
 'Vale of Glamorgan',
 'Warrington',
 'West Berkshire',
 'West Lothian',
 'Wiltshire',
 'Windsor and Maidenhead',
 'Wokingham',
 'York']

totaldata = pd.read_csv('Aberdeen City_symptoms_and_cases.csv')

for area in commonAreas:
    currentdata = pd.read_csv(area + '_symptoms_and_cases.csv')
    totaldata = pd.concat([totaldata, currentdata])

#totaldata.to_csv('Complete_Data.csv')
# Out:
#      symptom:Chest pain  symptom:Cough  symptom:Diarrhea  symptom:Fatigue  \
# 0                  4.47           9.24              8.60            12.82
# 1                  4.66           9.38              8.41            13.54
# 2                  5.33           9.97              8.89            13.93
# 3                  4.51           9.07              8.27            13.40
# 4                  4.60           8.12              8.54            14.28
# ..                  ...            ...               ...              ...
# 222                3.35           7.50              9.58            15.72
# 223                4.21           6.77              9.31            14.19
# 224                3.48           6.72             10.24            12.55
# 225                3.76           7.17             12.04            13.97
# 226                3.92           8.88             11.25            14.54
#
#      symptom:Fever  symptom:Headache  symptom:Migraine  \
# ...
